# %% [markdown]
# import neccessaty liberaries

# %%
import pandas as pd
import numpy as np
import sys
import os

sys.path.append(os.path.abspath('../scripts/'))
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/befekadum/AppData/Local/Microsoft/WindowsApps/python3.11.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
from eda_proccessor import EDA

# %%
data = pd.read_csv(r'C:\Users\befekadum\Documents\10x acadamy\week 3\-Insurance-Claim-Analysis\data\cleaned_data.csv')
# Out:
# C:\Users\befekadum\AppData\Local\Temp\ipykernel_28168\3440697963.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\Users\befekadum\Documents\10x acadamy\week 3\-Insurance-Claim-Analysis\data\cleaned_data.csv')

# %%
data
# Out:
#          Unnamed: 0  UnderwrittenCoverID  PolicyID     TransactionMonth  \
# 0                 0               145249     12827  2015-03-01 00:00:00
# 1                 1               145249     12827  2015-05-01 00:00:00
# 2                 2               145249     12827  2015-07-01 00:00:00
# 3                 3               145255     12827  2015-05-01 00:00:00
# 4                 4               145255     12827  2015-07-01 00:00:00
# ...             ...                  ...       ...                  ...
# 1000093     1000093                31520       389  2015-04-01 00:00:00
# 1000094     1000094                31520       389  2015-06-01 00:00:00
# 1000095     1000095                31520       389  2015-08-01 00:00:00
# 1000096     1000096                31519       389  2014-07-01 00:00:00
# 1000097     1000097                31519       389  2015-02-01 00:00:00
#
#          IsVATRegistered Citizenship          LegalType Title Language  \
# ...

# %% [markdown]
# instance the class

# %%
EDA = EDA(data)

# %% [markdown]
# Data Summarization

# %%
EDA.data_summarization()
# Out:
# Descriptive Statistics:
#
#          Unnamed: 0  UnderwrittenCoverID      PolicyID    PostalCode  \
# count  1.000098e+06         1.000098e+06  1.000098e+06  1.000098e+06
# mean   5.000485e+05         1.048175e+05  7.956682e+03  3.020601e+03
# std    2.887036e+05         6.329371e+04  5.290039e+03  2.649854e+03
# min    0.000000e+00         1.000000e+00  1.400000e+01  1.000000e+00
# 25%    2.500242e+05         5.514300e+04  4.500000e+03  8.270000e+02
# 50%    5.000485e+05         9.408300e+04  7.071000e+03  2.000000e+03
# 75%    7.500728e+05         1.391900e+05  1.107700e+04  4.180000e+03
# max    1.000097e+06         3.011750e+05  2.324600e+04  9.870000e+03
#
#              mmcode  RegistrationYear     Cylinders  cubiccapacity  \
# count  1.000098e+06      1.000098e+06  1.000098e+06   1.000098e+06
# mean   5.487770e+07      2.010225e+03  4.046642e+00   2.466743e+03
# std    1.360005e+07      3.261391e+00  2.939390e-01   4.426784e+02
# ...

# %% [markdown]
# Data Quality Assessment:

# %%
EDA.check_missing_values()
# Out:
# Missing Values Summary:
# NumberOfVehiclesInFleet    1000098
# dtype: int64

# %% [markdown]
# Univariate Analysis:

# %%
numerical_columns = data.select_dtypes(include=['number']).columns
print("Numerical columns:")
print(numerical_columns)
# Out:
# Numerical columns:
# Index(['Unnamed: 0', 'UnderwrittenCoverID', 'PolicyID', 'PostalCode', 'mmcode',
#        'RegistrationYear', 'Cylinders', 'cubiccapacity', 'kilowatts',
#        'NumberOfDoors', 'CustomValueEstimate', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'CalculatedPremiumPerTerm', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
categorical_columns = data.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:")
print(categorical_columns)
# Out:
# Categorical columns:
# Index(['TransactionMonth', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'VehicleType', 'make',
#        'Model', 'bodytype', 'VehicleIntroDate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'TermFrequency',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType'],
#       dtype='object')

# %%
EDA.plot_histograms(numerical_columns)

# %%
EDA.plot_bar_charts(categorical_columns)

# %%
EDA.plot_correlation_matrix('TotalPremium',
       'TotalClaims')

# %%
EDA.scatter_plot('MaritalStatus','CoverType')

# %%
EDA.scatter_plot('VehicleType','CoverType')

# %%
EDA.plot_trend_over_geography('CoverType','TotalPremium')
